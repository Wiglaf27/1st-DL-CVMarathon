# %%
作業1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')

plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.311

# %%
def mean_square_error(y, yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

MSE =  mean_square_error(y, y_hat)
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean square error is 207.508

# %%
作業2

# %%
1 選擇Solar Power Generation Data (https://www.kaggle.com/anikannal/solar-power-generation-data)
  透過所產電力及sensor資料，可調節產電效率及維修/保養頻率，使產電效能維持在一定水準
2 資料為位於印度的solar power plants在34天間的資料
3 資料型態為針對各時間區間而有的相應產電數值資料，單位為kW
4 為尋求最佳配置solar power panel的方式，其可能為迴歸問題以求最佳解，故可能以MAE、RMSE作為指標

# %%
作業3

# %%
1 如何更有效的投放車隊廣告以提升載客數，並如何減少在離峰時段的車子油耗以降低成本
2 收集各大SNS廣告投放效率資料；記錄載客數較少的時段並考慮減少空車於街上繞行的時間
3 廣告投放效率資料，其型態可能為針對使用時間的廣告密度數值；載客數相對時間的資料亦為相似時間密度數值
4 為求最佳解可將問題設計為一迴歸問題，以MAE、RMSE作為指標
